# %% [markdown]
# ### Importing the necessary libraries and packages

# %%
from sklearn.model_selection import train_test_split # splitting the dataset
from sklearn.linear_model import LinearRegression # regression algorithm
from sklearn.metrics import r2_score # accuracy metric
import pandas as pd # data processing 
import matplotlib.pyplot as plt # data plotting
import seaborn as sb # data plotting

# %% [markdown]
# ### Importing the csv file as a dataFrame

# %%
df = pd.read_csv("Heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %% [markdown]
# ### Now taking 2 parts from the dataset:
# #### X: which contains only the <b>age</b> column<br>Y: which contains only the <b>target</b> column

# %%
X = df.loc[:,["cp"]]
y = df.loc[:,["target"]]
print("//Independent features//")
print(X.head())
print("\n\n//Dependent feature//")
print(y.head())
# Out:
# //Independent features//
#    cp
# 0   3
# 1   2
# 2   1
# 3   1
# 4   0
#
#
# //Dependent feature//
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Split the <b>X</b> and <b>y</b> dataframes for test and training

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=42)

# %% [markdown]
# # Simple Linear Regression

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
# printing the r2_score of regression
print("The coefficient of determination :", r2_score(y_test,y_pred))
# Out:
# The coefficient of determination : 0.11491959597381063

# %% [markdown]
# ## Plotting the regression

# %%
plt.figure(figsize=(10, 10))
sb.regplot(x="cp",y="target",data=df)
