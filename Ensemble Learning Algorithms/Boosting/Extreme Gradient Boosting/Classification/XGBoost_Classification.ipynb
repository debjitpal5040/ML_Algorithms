# %%
import matplotlib.pyplot as plt  # data plotting
import numpy as np  # data processing
import pandas as pd  # data processing
from joblib import dump  # saving the model
from sklearn.datasets import load_breast_cancer  # loading the dataset
from sklearn.metrics import ConfusionMatrixDisplay  # accuracy metrics
from sklearn.metrics import (
    accuracy_score,
    auc,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split  # splitting the dataset
from xgboost import XGBClassifier  # XGBoost Classifier

# %%
def sklearn_to_df(sklearn_dataset):
    df = pd.DataFrame(sklearn_dataset.data, columns=sklearn_dataset.feature_names)
    df["target"] = pd.Series(sklearn_dataset.target)
    return df


breast_cancer = load_breast_cancer()
df_breast_cancer = sklearn_to_df(breast_cancer)
df_breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
X = df_breast_cancer.iloc[:, :-1].values
y = df_breast_cancer.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
xgbc = XGBClassifier(
    objective="binary:logistic",
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    n_jobs=-1,
)
xgbc.fit(X_train, y_train)
y_pred = xgbc.predict(X_test)

# %%
xgbc_con_matrix = confusion_matrix(y_test, y_pred)
xgbc_acc = accuracy_score(y_test, y_pred)
print("Confusion Matrix", "\n", xgbc_con_matrix, "\n")
print("Accuracy of Extreme Gradient Boosting Classification :", xgbc_acc * 100, "\n")
print("Classification Report", "\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[22  0]
#  [ 1 34]]
#
# Accuracy of Extreme Gradient Boosting Classification : 98.24561403508771
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        22
#            1       1.00      0.97      0.99        35
#
#     accuracy                           0.98        57
#    macro avg       0.98      0.99      0.98        57
# weighted avg       0.98      0.98      0.98        57

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=150)
plt.style.use("dark_background")
ConfusionMatrixDisplay(xgbc_con_matrix).plot(ax=ax)
plt.title("Confusion Matrix")
plt.savefig(
    "Images/Confusion_Matrix_Extreme_Gradient_Boosting_Classification.png",
    bbox_inches="tight",
)

# %%
y_score = xgbc.predict_proba(X_test)[:, 1]
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, y_score)
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use("dark_background")
plt.plot(false_positive_rate, true_positive_rate, "r", label="AUC = %f" % roc_auc)
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.plot([0, 1], [0, 1], "b--")
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.savefig(
    "Images/ROC_Curve_Extreme_Gradient_Boosting_Classification.png", bbox_inches="tight"
)

# %%
print(
    "Area Under the Receiver Operating Characteristic Curve :",
    roc_auc_score(y_test, y_score),
)
# Out:
# Area Under the Receiver Operating Characteristic Curve : 0.9974025974025974

# %%
dump(xgbc, "extremeGradientBoostingClassifier.joblib")
# Out:
# ['extremeGradientBoostingClassifier.joblib']
