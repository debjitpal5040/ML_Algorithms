# %% [markdown]
# # Bagging Classification

# %%
import pandas as pd
from joblib import dump
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../../Datasets/SocialNetworkAds.csv")
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       2   26            43000          0
# 3       2   27            57000          0
# 4       1   19            76000          0

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
bagging = BaggingClassifier()
bagging.fit(X_train, y_train)
y_pred = bagging.predict(X_test)

# %%
bagging_con_matrix = confusion_matrix(y_test, y_pred)
bagging_acc = accuracy_score(y_test, y_pred)
print("Confusion Matrix", "\n", bagging_con_matrix, "\n")
print("Accuracy of Bagging Classification :", bagging_acc * 100, "\n")  # type: ignore
print("Classification Report", "\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[30  2]
#  [ 3  5]]
#
# Accuracy of Bagging Classification : 87.5
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        32
#            1       0.71      0.62      0.67         8
#
#     accuracy                           0.88        40
#    macro avg       0.81      0.78      0.79        40
# weighted avg       0.87      0.88      0.87        40

# %%
dump(bagging, "../../Models/baggingClassifier.joblib")
# Out:
# ['../../Models/baggingClassifier.joblib']
