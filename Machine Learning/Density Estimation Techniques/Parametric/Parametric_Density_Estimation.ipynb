# %%
# example of parametric probability density estimation
from matplotlib import pyplot as plt
from numpy.random import normal
from numpy import mean, std
from scipy.stats import norm
# generate a sample of size 200 with mean 50 and std 5
sample = normal(loc=50, scale=5, size=200)
# calculate parameters
sample_mean = mean(sample)
sample_std = std(sample)
print("Actual sample mean:", sample_mean)
print("Actual sample std:", sample_std)
minima = min(sample)
maxima = max(sample)
# Out:
# Actual sample mean: 50.100699118855886
# Actual sample std: 4.768530376627675

# %% [markdown]
# ## Visualization of sample

# %%
plt.figure(figsize=(8, 4), dpi=150)
plt.hist(sample, density=True)
# Out:
# (array([0.00366332, 0.00549498, 0.01465327, 0.03113819, 0.07692966,
#         0.08791961, 0.06777136, 0.05494975, 0.01648493, 0.00732663]),
#  array([34.85598747, 37.58575403, 40.31552058, 43.04528714, 45.7750537 ,
#         48.50482026, 51.23458681, 53.96435337, 56.69411993, 59.42388648,
#         62.15365304]),
#  <a list of 10 Patch objects>)

# %%
# define the distribution
dist = norm(sample_mean, sample_std)

# %%
# sample probabilities for all ranges of outcomes
values = [value for value in range(round(minima), round(maxima)+1)]
probabilities = [dist.pdf(value) for value in values]

# %%
# plot the histogram and pdf
plt.figure(figsize=(8, 4), dpi=150)
plt.hist(sample, density=True)
plt.plot(values, probabilities)
