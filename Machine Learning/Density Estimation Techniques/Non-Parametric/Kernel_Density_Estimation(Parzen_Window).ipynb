# %%
# example of a bimodal data sample
from matplotlib import pyplot as plt
from numpy.random import normal
from numpy import hstack, asarray, exp
from sklearn.neighbors import KernelDensity
# generate a sample
sample1 = normal(loc=20, scale=5, size=300)
sample2 = normal(loc=40, scale=5, size=700)
sample = hstack((sample1, sample2))
# plot the histogram
plt.figure(figsize=(8, 4), dpi=150)
plt.hist(sample, bins=50)
# Out:
# (array([ 1.,  1.,  2.,  3.,  1.,  4.,  6., 10., 14.,  9., 18., 14., 33.,
#         20., 19., 30., 16., 26., 20., 16., 15.,  5., 11., 10.,  7., 19.,
#         19., 25., 41., 35., 46., 41., 54., 51., 55., 51., 42., 48., 41.,
#         32., 27., 15., 10., 15., 11.,  5.,  2.,  0.,  2.,  2.]),
#  array([ 5.41628898,  6.43045809,  7.44462719,  8.4587963 ,  9.4729654 ,
#         10.48713451, 11.50130361, 12.51547272, 13.52964182, 14.54381093,
#         15.55798003, 16.57214914, 17.58631825, 18.60048735, 19.61465646,
#         20.62882556, 21.64299467, 22.65716377, 23.67133288, 24.68550198,
#         25.69967109, 26.71384019, 27.7280093 , 28.74217841, 29.75634751,
#         30.77051662, 31.78468572, 32.79885483, 33.81302393, 34.82719304,
#         35.84136214, 36.85553125, 37.86970035, 38.88386946, 39.89803857,
#         40.91220767, 41.92637678, 42.94054588, 43.95471499, 44.96888409,
#         45.9830532 , 46.9972223 , 48.01139141, 49.02556051, 50.03972962,
#         51.05389872, 52.06806783, 53.08223694, 54.09640604, 55.11057515,
#         56.12474425]),
#  <a list of 50 Patch objects>)

# %%
# fit density
model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=2)

# %%
# sample probabilities for a range of outcomes
values = asarray([value for value in range(1, 60)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = exp(probabilities)

# %%
# plot the histogram and pdf
plt.figure(figsize=(8, 4), dpi=150)
plt.hist(sample, bins=50, density=True)
plt.plot(values[:], probabilities)
