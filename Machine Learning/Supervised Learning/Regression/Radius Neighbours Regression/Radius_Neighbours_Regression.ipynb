# %% [markdown]
# # Radius Neighbours Regression

# %% [markdown]
# ## Importing the necessary Libraries and Packages

# %%
from sklearn.model_selection import train_test_split  # splitting the dataset
from sklearn.neighbors import RadiusNeighborsRegressor # regression model
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error, mean_absolute_percentage_error  # accuracy metrics
from joblib import dump  # saving the model
import numpy as np  # data processing
import pandas as pd  # data processing
import matplotlib.pyplot as plt  # data plotting

# %% [markdown]
# ## Importing the csv file as a DataFrame

# %%
df = pd.read_csv('IceCreamData.csv')
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Formal information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# Description of the dataset

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %% [markdown]
# Checking if any null value exists

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %% [markdown]
# Columns of the dataset

# %%
df.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %% [markdown]
# Correlations between the variables

# %%
df.corr()
# Out:
#              Temperature   Revenue
# Temperature     1.000000  0.989802
# Revenue         0.989802  1.000000

# %% [markdown]
# ## Now taking 2 parts from the dataset
#
# ### X: which contains only the <b>Temperature</b> column<br>Y: which contains only the <b>Revenue</b> column

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Visualisation of the Data

# %%
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
Temperature = df['Temperature']
Revenue = df['Revenue']
plt.scatter(Temperature, Revenue, marker='.', color='red')
plt.xticks(np.arange(0, 48, 3))
plt.yticks(np.arange(10, 1100, 100))
plt.title('Temperature vs Revenue')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.savefig('Images/Temperature_vs_Revenue.png', bbox_inches='tight')

# %% [markdown]
# ## Split the X and y dataframes for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %% [markdown]
# ## Finding the best value of Radius for RN Regression

# %%
n = X_train.shape[0]
rmse_val = []
for K in range(1 , int(n**0.3)+1):  
    model = RadiusNeighborsRegressor(radius=K)
    model.fit(X_train, y_train)  
    pred = model.predict(X_test)  
    rmse_val.append(mean_squared_error(y_test, pred, squared=False))  
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
plt.plot(range(1, int(n**0.3)+1), rmse_val, linestyle='dashed', color='blue', marker='o', markerfacecolor='red')
plt.xticks(np.arange(1 , int(n**0.3)+1, 1))
plt.yticks(np.arange(20, 31, 2))
plt.xlabel('Value of Radius')
plt.ylabel('RMSE')
plt.title('Value of Radius vs RMSE')
plt.savefig('Images/Value_of_Radius_vs_MSE.png', bbox_inches='tight')

# %% [markdown]
# ## Implementation of the Model

# %%
rnr = RadiusNeighborsRegressor(radius=2)
rnr.fit(X_train, y_train)
y_pred = rnr.predict(X_test)

# %% [markdown]
# ## Performance of the Model

# %%
print('The coefficient of determination :', r2_score(y_test, y_pred))
adjusted_r2_score = 1-((1-r2_score(y_test, y_pred))*(len(y_test)-1))/(len(y_test)-X_test.shape[1]-1)
print('The adjusted coefficient of determination :', adjusted_r2_score)
# Out:
# The coefficient of determination : 0.9813536153810911
# The adjusted coefficient of determination : 0.9809651490348639

# %% [markdown]
# ## Plotting the Regression

# %% [markdown]
# ### Training Dataset

# %%
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
X_train_grid = np.arange(min(X_train), max(X_train), 0.01)
X_train_grid = X_train_grid.reshape((len(X_train_grid), 1))
plt.scatter(X_train, y_train, marker='.', color='red')
plt.plot(X_train_grid, rnr.predict(X_train_grid), color='blue')
plt.xticks(np.arange(0, 48, 3))
plt.yticks(np.arange(10, 1100, 100))
plt.title('Temperature vs Revenue (Training set)')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.savefig('Images/Training_set.png', bbox_inches='tight')

# %% [markdown]
# ### Test Dataset

# %%
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
X_test_grid = np.arange(min(X_test), max(X_test), 0.01)
X_test_grid = X_test_grid.reshape((len(X_test_grid), 1))
plt.scatter(X_test, y_test, marker='.', color='red')
plt.plot(X_test_grid, rnr.predict(X_test_grid), color='blue')
plt.xticks(np.arange(0, 48, 3))
plt.yticks(np.arange(10, 1100, 100))
plt.title('Temperature vs Revenue (Test set)')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.savefig('Images/Test_set.png', bbox_inches='tight')

# %% [markdown]
# ## Additional Performance Metrics

# %%
print('Mean Absolute Error (MAE) :', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error (MSE) :', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error (RMSE) :', mean_squared_error(y_test, y_pred, squared=False))
print('Mean Squared Log Error (MSLE) :', mean_squared_log_error(y_test, y_pred))
print('Root Mean Squared Log Error (RMSLE) :', mean_squared_log_error(y_test, y_pred, squared=False))
print('Mean Absolute Percentage Error (MAPE) :', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Mean Absolute Error (MAE) : 17.478124079254677
# Mean Squared Error (MSE) : 455.9033905352209
# Root Mean Squared Error (RMSE) : 21.35189430788802
# Mean Squared Log Error (MSLE) : 0.0017932017610990969
# Root Mean Squared Log Error (RMSLE) : 0.04234621306680323
# Mean Absolute Percentage Error (MAPE) : 0.03493418865844453

# %% [markdown]
# ## Saving the model

# %%
dump(rnr, 'rnRegressor.joblib')
# Out:
# ['rnRegressor.joblib']
