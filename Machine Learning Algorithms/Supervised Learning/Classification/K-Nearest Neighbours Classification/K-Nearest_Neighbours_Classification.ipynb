# %% [markdown]
# # K-Nearest Neighbours Classification

# %% [markdown]
# ## Importing the necessary libraries and packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from joblib import dump
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    accuracy_score,
    auc,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Importing the csv file as a dataFrame

# %%
df = pd.read_csv("../../../../Datasets/SocialNetworkAds.csv")
df.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       2   26            43000          0
# 3       2   27            57000          0
# 4       1   19            76000          0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Formal information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    int64
#  1   Age              400 non-null    int64
#  2   EstimatedSalary  400 non-null    int64
#  3   Purchased        400 non-null    int64
# dtypes: int64(4)
# memory usage: 12.6 KB

# %% [markdown]
# Description of the dataset

# %%
df.describe()
# Out:
#            Gender         Age  EstimatedSalary   Purchased
# count  400.000000  400.000000       400.000000  400.000000
# mean     1.510000   37.655000     69742.500000    0.357500
# std      0.500526   10.482877     34096.960282    0.479864
# min      1.000000   18.000000     15000.000000    0.000000
# 25%      1.000000   29.750000     43000.000000    0.000000
# 50%      2.000000   37.000000     70000.000000    0.000000
# 75%      2.000000   46.000000     88000.000000    1.000000
# max      2.000000   60.000000    150000.000000    1.000000

# %% [markdown]
# Checking if any null value exists

# %%
df.isnull().sum()
# Out:
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# Columns of the dataset

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %% [markdown]
# Correlations between the variables

# %%
df.corr()
# Out:
#                    Gender       Age  EstimatedSalary  Purchased
# Gender           1.000000  0.073741         0.060435   0.042469
# Age              0.073741  1.000000         0.155238   0.622454
# EstimatedSalary  0.060435  0.155238         1.000000   0.362083
# Purchased        0.042469  0.622454         0.362083   1.000000

# %% [markdown]
# ## Now taking 2 parts from the dataset
#
# ### X: which contains all columns except the <b>target</b> column<br>Y: which contains only the <b>target</b> column

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Split the <b>X</b> and <b>y</b> Dataframes for Test and Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %% [markdown]
# ## Finding the best value of K for KNN Classification

# %%
n = X_train.shape[0]
rmse_val = []
for K in range(1, int(n**0.5) + 1):
    model = KNeighborsClassifier(n_neighbors=K)
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    rmse_val.append(100 * accuracy_score(y_test, pred))
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use("dark_background")
plt.plot(
    range(1, int(n**0.5) + 1),
    rmse_val,
    linestyle="dashed",
    color="blue",
    marker="o",
    markerfacecolor="red",
)
plt.xticks(np.arange(1, int(n**0.5) + 1, 2))
plt.yticks(np.arange(85, 100, 2))
plt.xlabel("Value of K")
plt.ylabel("Accuracy (%)")
plt.title("Value of K vs Accuracy")
plt.savefig("Images/Value_of_K_vs_Accuracy.png", bbox_inches="tight")

# %% [markdown]
# ## Implementation of the Model

# %%
knnc = KNeighborsClassifier(n_neighbors=8)
knnc.fit(X_train, y_train)
y_pred = knnc.predict(X_test)

# %% [markdown]
# ## Performance of the Model

# %%
knnc_con_matrix = confusion_matrix(y_test, y_pred)
knnc_acc = accuracy_score(y_test, y_pred)
print("Confusion Matrix", "\n", knnc_con_matrix, "\n")
print("Accuracy of K-Nearest Neighbours Classification :", knnc_acc * 100, "\n")
print("Classification Report", "\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[31  1]
#  [ 2  6]]
#
# Accuracy of K-Nearest Neighbours Classification : 92.5
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        32
#            1       0.86      0.75      0.80         8
#
#     accuracy                           0.93        40
#    macro avg       0.90      0.86      0.88        40
# weighted avg       0.92      0.93      0.92        40

# %% [markdown]
# ## Plotting the Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=150)
plt.style.use("dark_background")
ConfusionMatrixDisplay(knnc_con_matrix).plot(ax=ax)
plt.title("Confusion Matrix")
plt.savefig(
    "Images/Confusion_Matrix_K-Nearest_Neighbours_Classification.png",
    bbox_inches="tight",
)

# %% [markdown]
# ## Plotting the ROC curve

# %%
y_score = knnc.predict_proba(X_test)[:, 1]  # type: ignore
fpr, tpr, threshold = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=150)
plt.style.use("dark_background")
RocCurveDisplay(
    fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name="K-Nearest Neighbours Classifier"
).plot(ax=ax)
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.plot([0, 1], [0, 1], "b--")
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.savefig(
    "Images/ROC_Curve_K-Nearest_Neighbours_Classification.png", bbox_inches="tight"
)

# %% [markdown]
# ## Computing the AUC of ROC

# %%
print(
    "Area Under the Receiver Operating Characteristic Curve :",
    roc_auc_score(y_test, y_score),
)
# Out:
# Area Under the Receiver Operating Characteristic Curve : 0.853515625

# %% [markdown]
# ## Saving the model

# %%
dump(knnc, "../../../../Models/k-NearestNeighboursClassifier.joblib")
# Out:
# ['../../../../Models/k-NearestNeighboursClassifier.joblib']
