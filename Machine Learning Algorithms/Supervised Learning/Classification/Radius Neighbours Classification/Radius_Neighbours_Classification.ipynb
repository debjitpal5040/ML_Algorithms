# %% [markdown]
# # Radius Neighbours Classification

# %% [markdown]
# ## Importing the necessary libraries and packages

# %%
import matplotlib.pyplot as plt  # data plotting
import numpy as np  # data processing
import pandas as pd  # data processing
from joblib import dump  # saving the model
from sklearn.datasets import load_breast_cancer  # loading the dataset
from sklearn.metrics import (ConfusionMatrixDisplay,  # accuracy metrics
                             RocCurveDisplay, accuracy_score, auc,
                             classification_report, confusion_matrix,
                             roc_auc_score, roc_curve)
from sklearn.model_selection import train_test_split  # splitting the dataset
from sklearn.neighbors import \
    RadiusNeighborsClassifier  # classification algorithm

# %% [markdown]
# ## Importing the csv file as a dataFrame

# %%
def sklearn_to_df(sklearn_dataset):
    df = pd.DataFrame(sklearn_dataset.data, columns=sklearn_dataset.feature_names)
    df['target'] = pd.Series(sklearn_dataset.target)
    return df
breast_cancer = load_breast_cancer()
df_breast_cancer = sklearn_to_df(breast_cancer)
df_breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Formal information about the dataset

# %%
df_breast_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# Description of the dataset

# %%
df_breast_cancer.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# Checking if any null value exists

# %%
df_breast_cancer.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %% [markdown]
# Columns of the dataset

# %%
df_breast_cancer.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %% [markdown]
# Correlations between the variables

# %%
df_breast_cancer.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %% [markdown]
# ## Now taking 2 parts from the dataset
# ### X: which contains all columns except the <b>target</b> column<br>Y: which contains only the <b>target</b> column

# %%
X = df_breast_cancer.iloc[:, :-1].values
y = df_breast_cancer.iloc[:, -1].values

# %% [markdown]
# ## Split the <b>X</b> and <b>y</b> Dataframes for Test and Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %% [markdown]
# ## Finding the best value of Radius for RN Classification

# %%
n = X_train.shape[0]
rmse_val = []
for K in range(n//5, n//4+1):  
    model = RadiusNeighborsClassifier(radius=K, outlier_label='most_frequent')
    model.fit(X_train, y_train)  
    pred = model.predict(X_test)  
    rmse_val.append(100*accuracy_score(y_test, pred)) 
plt.figure(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
plt.plot(range(n//5, n//4+1), rmse_val, linestyle='dashed', color='blue', marker='o', markerfacecolor='red')
plt.xticks(np.arange(n//5, n//4+1, 3))
plt.yticks(np.arange(90, 100, 2))
plt.xlabel('Value of Radius')
plt.ylabel('Accuracy (%)')
plt.title('Value of Radius vs Accuracy')
plt.savefig('Images/Value_of_Radius_vs_Accuracy.png', bbox_inches='tight')

# %% [markdown]
# ## Implementation of the Model

# %%
rnc = RadiusNeighborsClassifier(radius=120)
rnc.fit(X_train, y_train)
y_pred = rnc.predict(X_test)

# %% [markdown]
# ## Performance of the Model

# %%
rnc_con_matrix = confusion_matrix(y_test, y_pred)
rnc_acc = accuracy_score(y_test, y_pred)
print('Confusion Matrix', '\n', rnc_con_matrix, '\n')
print('Accuracy of Radius Neighbours Classification :', rnc_acc*100, '\n')
print('Classification Report', '\n', classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[20  2]
#  [ 1 34]]
#
# Accuracy of Radius Neighbours Classification : 94.73684210526315
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        22
#            1       0.94      0.97      0.96        35
#
#     accuracy                           0.95        57
#    macro avg       0.95      0.94      0.94        57
# weighted avg       0.95      0.95      0.95        57

# %% [markdown]
# ## Plotting the Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
ConfusionMatrixDisplay(rnc_con_matrix).plot(ax=ax)
plt.title('Confusion Matrix')
plt.savefig('Images/Confusion_Matrix_Radius_Neighbours_Classification.png', bbox_inches='tight')

# %% [markdown]
# ## Plotting the ROC curve

# %%
y_score = rnc.predict_proba(X_test)[:, 1]
fpr, tpr, threshold = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

# %%
fig, ax = plt.subplots(figsize=(6, 6), dpi=150)
plt.style.use('dark_background')
RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name='Radius Neighbours Classifier').plot(ax=ax)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot([0, 1], [0, 1], 'b--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.savefig('Images/ROC_Curve_Radius_Neighbours_Classification.png', bbox_inches='tight')

# %% [markdown]
# ## Computing the AUC of ROC

# %%
print('Area Under the Receiver Operating Characteristic Curve :', roc_auc_score(y_test, y_score))
# Out:
# Area Under the Receiver Operating Characteristic Curve : 0.9766233766233767

# %% [markdown]
# ## Saving the model

# %%
dump(rnc, 'rnClassifier.joblib')
# Out:
# ['rnClassifier.joblib']
